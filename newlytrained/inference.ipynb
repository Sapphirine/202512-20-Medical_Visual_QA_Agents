# %%
# CLIP + tinyllama + multitoken
import os
import torch
import numpy as np
import torch.nn as nn
from tqdm import tqdm
import re
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, CLIPVisionModel, CLIPImageProcessor

device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)

# ======================================================
# 1. 超参数：视觉 token 个数（必须和训练时一致）
# ======================================================
NUM_VISION_TOKENS = 4

# ======================================================
# 2. 加载 CLIP Vision
# ======================================================
clip_name = "openai/clip-vit-base-patch32"
clip_vision = CLIPVisionModel.from_pretrained(clip_name).to(device)
clip_processor = CLIPImageProcessor.from_pretrained(clip_name)

for p in clip_vision.parameters():
    p.requires_grad = False

vision_width = clip_vision.config.hidden_size
print("CLIP hidden_size =", vision_width)

# ======================================================
# 3. 加载 TinyLLaMA（冻结）
# ======================================================
llama_name = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"
tokenizer = AutoTokenizer.from_pretrained(llama_name)

llama = AutoModelForCausalLM.from_pretrained(
    llama_name,
    torch_dtype=torch.float16,
).to(device)

for p in llama.parameters():
    p.requires_grad = False

lm_hidden_size = llama.config.hidden_size
print("LLaMA hidden =", lm_hidden_size)

# ======================================================
# 4. 定义 Projector（必须和训练时一致）
# ======================================================
class Projector(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.linear1 = nn.Linear(in_dim, out_dim)
        self.act = nn.GELU()
        self.linear2 = nn.Linear(out_dim, out_dim)

    def forward(self, x):
        if x.dim() == 2:
            x = x.unsqueeze(1)
        x = self.linear1(x)
        x = self.act(x)
        x = self.linear2(x)
        return x

projector = Projector(vision_width, lm_hidden_size).to(device)

# ======================================================
# 5. 加载你训练好的 projector 权重
# ======================================================
weight_path = "/workspace/CLIP+tinyllama+multitoken/projector_epoch1.pt"
projector.load_state_dict(torch.load(weight_path, map_location=device))
projector.eval()
print(f"Loaded trained projector: {weight_path}")

# ======================================================
# 6. 定义多视觉 token 提取函数（和训练完全一致）
# ======================================================
def extract_vision_embeds(img):
    clip_inputs = clip_processor(images=img, return_tensors="pt").to(device)

    with torch.no_grad():
        vision_outputs = clip_vision(**clip_inputs)
        patch_tokens = vision_outputs.last_hidden_state[:, 1:, :]  # remove CLS

    B, S, C = patch_tokens.shape
    num_tokens = NUM_VISION_TOKENS

    # 均匀分 N 组
    if S < num_tokens:
        repeat_factor = (num_tokens + S - 1)//S
        patch_tokens = patch_tokens.repeat(1, repeat_factor, 1)
        S = patch_tokens.size(1)

    chunk_size = S // num_tokens
    usable_len = chunk_size * num_tokens
    patch_tokens = patch_tokens[:, :usable_len, :]
    patch_tokens = patch_tokens.view(B, num_tokens, chunk_size, C)
    patch_tokens = patch_tokens.mean(dim=2)  # (B, NUM_TOKENS, C)

    embeds_f32 = projector(patch_tokens)
    embeds = embeds_f32.to(torch.float16)
    return embeds

# ======================================================
# 7. PathVQA 测试集
# ======================================================
test_ds = load_dataset("flaviagiammarino/path-vqa", split="test")
N = 200   # 想推理多少条就写多少
test_ds = test_ds.select(range(N))

print("Test samples =", len(test_ds))

# ======================================================
# 8. 指标
# ======================================================
def normalize(s):
    s = s.lower().strip()
    s = re.sub(r"[^a-z0-9]+", " ", s)
    return " ".join(s.split())

def f1(pred, gt):
    pt = normalize(pred).split()
    gt = normalize(gt).split()
    if len(pt)==0 or len(gt)==0:
        return float(pt==gt)
    common = set(pt) & set(gt)
    if not common: return 0.0
    p = len(common)/len(pt)
    r = len(common)/len(gt)
    return 2*p*r/(p+r)

def em(pred, gt):
    return float(normalize(pred)==normalize(gt))

# ======================================================
# 9. 进行推理
# ======================================================
all_f1 = []
all_em = []
predictions = []

for sample in tqdm(test_ds, desc="Infer Test Set"):
    img = sample["image"]
    question = sample["question"]
    answer_gt = sample["answer"]

    # 多视觉 token
    with torch.no_grad():
        vision_embeds = extract_vision_embeds(img)

        prompt = f"Question: {question}\nAnswer:"
        tok = tokenizer(prompt, return_tensors="pt")
        input_ids = tok.input_ids.to(device)

        text_emb = llama.model.embed_tokens(input_ids)

        inputs_embeds = torch.cat([vision_embeds, text_emb], dim=1)

        output = llama.generate(
            inputs_embeds=inputs_embeds,
            max_new_tokens=32,
            do_sample=False,
        )

        pred = tokenizer.decode(output[0], skip_special_tokens=True)
        pred = pred.split("Answer:")[-1].strip().split("\n")[0].strip()

    all_f1.append(f1(pred, answer_gt))
    all_em.append(em(pred, answer_gt))
    predictions.append((question, answer_gt, pred))

# ======================================================
# 10. 输出测试集结果
# ======================================================
print("\n=== Test Set Results ===")
print("Samples:", len(test_ds))
print("F1 =", np.mean(all_f1))
print("EM =", np.mean(all_em))

# 如果你想看到一些预测样例：
print("\n=== Example Predictions ===")
for i in range(20):
    q, gt, pd = predictions[i]
    print(f"Q: {q}\nGT: {gt}\nPD: {pd}\n")
# Out:
# Device: cuda
# CLIP hidden_size = 768
# LLaMA hidden = 2048
# Loaded trained projector: /workspace/CLIP+tinyllama+multitoken/projector_epoch1.pt
# Test samples = 200
# Infer Test Set: 100%|██████████| 200/200 [01:25<00:00,  2.35it/s]
# === Test Set Results ===
# Samples: 200
# F1 = 0.30269507270934815
# EM = 0.28
#
# === Example Predictions ===
# Q: what are positively charged, thus allowing the compaction of the negatively charged dna?
# GT: the histone subunits
# PD: the cytoplasm of the cell is the dna, which is the genetic material of the cell, and the cytoplasm of the cell
#
# Q: how are the histone subunits charged?
# GT: positively charged
# PD: by the phosphatidine phosphatidine phosphatidine phosphatidine phosphatidine phosphatidine
#
# Q: what is showing increased eosinophilia of cytoplasm, and swelling of occasional cells?
# GT: early (reversible) ischemic injury
# PD: the tumor is a large, irregularly shaped mass of cells, which is the most common type of tumor in the body, and is usually found
#
# Q: does mycobacterium avium infection in a duodenal biopsy from a patient with aids show massive intracellular macrophage infection with acid-fast organisms filamentous and pink in this acid-fast stain preparation?
# GT: yes
# PD: no
#
# Q: what shows branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: microscopy
# PD: the image shows a small, round, flattened, and flattened, and covered by a single layer of cuboidal cells, with a single
#
# Q: does microscopy show branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: yes
# PD: no, it shows a single layer of cuboidal cells having ground-glass nuclei
#
# Q: does pbf show branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: no
# PD: no
#
# Q: what is involvedd in pathogenesis of two main types of diabetes mellitus?
# GT: chematic mechanisms
# PD: the disease is characterized by the presence of two main types of diabetes mellitus, which are the following:
#
# Q: what is chematic mechanisms involved in?
# GT: pathogenesis of two main types of diabetes mellitus
# PD: the tumor is a neoplastic carcinoma of the small intestine, which is a neoplastic carcinoma of the small
#
# Q: is chematic mechanisms involved in pathogenesis of two main types of diabetes mellitus?
# GT: yes
# PD: no
#
# Q: are numbers in the illustrations involved in pathogenesis of two main types of diabetes mellitus?
# GT: no
# PD: no
#
# Q: what shows trabeculae with osteoclastic activity at the margins?
# GT: trabecular bone forming the marrow space
# PD: the tumor shows a large number of cells with a high degree of similarity to the tumor cells of the osteoclastic tissue, which are
#
# Q: what does the trabecular bone forming the marrow space show at the margins?
# GT: trabeculae with osteoclastic activity
# PD: the bone shows a large amount of the marrow space, which is the site of the tumor, and the tumor shows a large amount of the
#
# Q: where does the trabecular bone forming the marrow space show?
# GT: at the margins
# PD: in the right hemisphere, the trabecular bone forming the marrow space shows up in the right hemisphere, the trabecular b
#
# Q: are there inadequate t cells to mount a granulomatous response?
# GT: yes
# PD: no
#
# Q: how does the trabecular bone forming the marrow space show trabeculae?
# GT: with osteoclastic activity
# PD: shows the presence of the bone in the marrow space, which is a sign of the presence of the bone in the marrow space, which is
#
# Q: does the trabecular bone forming the marrow space show trabeculae with osteoclastic activity at the margins?
# GT: yes
# PD: no
#
# Q: does the upper dermis show trabeculae with osteoclastic activity at the margins?
# GT: no
# PD: no
#
# Q: what shows concentric lamellae along with osteocytic lacunae surrounding central blood vessels, while the trabecular bone forming the marrow space shows trabeculae with osteoclastic activity at the margins?
# GT: cortical bone forming the outer shell
# PD: the trabecular bone shows a well-defined trabecular space with a central space of osteoclastic activity, which is the site of
#
# Q: what does the cortical bone forming the outer shell show?
# GT: concentric lamellae along with osteocytic lacunae surrounding central blood vessels
# PD: the brain shows the following:

# %%
# CLIP_tinyllama_LORA

# 如果你想看到一些预测样例：
print("\n=== Example Predictions ===")
for i in range(190):
    q, gt, pd = predictions[i]
    print(f"Q: {q}\nGT: {gt}\nPD: {pd}\n")
# Out:
# === Example Predictions ===
# Q: what are positively charged, thus allowing the compaction of the negatively charged dna?
# GT: the histone subunits
# PD: the cytoplasm of the cell is the dna, which is the genetic material of the cell, and the cytoplasm of the cell
#
# Q: how are the histone subunits charged?
# GT: positively charged
# PD: by the phosphatidine phosphatidine phosphatidine phosphatidine phosphatidine phosphatidine
#
# Q: what is showing increased eosinophilia of cytoplasm, and swelling of occasional cells?
# GT: early (reversible) ischemic injury
# PD: the tumor is a large, irregularly shaped mass of cells, which is the most common type of tumor in the body, and is usually found
#
# Q: does mycobacterium avium infection in a duodenal biopsy from a patient with aids show massive intracellular macrophage infection with acid-fast organisms filamentous and pink in this acid-fast stain preparation?
# GT: yes
# PD: no
#
# Q: what shows branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: microscopy
# PD: the image shows a small, round, flattened, and flattened, and covered by a single layer of cuboidal cells, with a single
#
# Q: does microscopy show branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: yes
# PD: no, it shows a single layer of cuboidal cells having ground-glass nuclei
#
# Q: does pbf show branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: no
# PD: no
#
# Q: what is involvedd in pathogenesis of two main types of diabetes mellitus?
# GT: chematic mechanisms
# PD: the disease is characterized by the presence of two main types of diabetes mellitus, which are the following:
#
# Q: what is chematic mechanisms involved in?
# GT: pathogenesis of two main types of diabetes mellitus
# PD: the tumor is a neoplastic carcinoma of the small intestine, which is a neoplastic carcinoma of the small
#
# Q: is chematic mechanisms involved in pathogenesis of two main types of diabetes mellitus?
# GT: yes
# PD: no
#
# Q: are numbers in the illustrations involved in pathogenesis of two main types of diabetes mellitus?
# GT: no
# PD: no
#
# Q: what shows trabeculae with osteoclastic activity at the margins?
# GT: trabecular bone forming the marrow space
# PD: the tumor shows a large number of cells with a high degree of similarity to the tumor cells of the osteoclastic tissue, which are
#
# Q: what does the trabecular bone forming the marrow space show at the margins?
# GT: trabeculae with osteoclastic activity
# PD: the bone shows a large amount of the marrow space, which is the site of the tumor, and the tumor shows a large amount of the
#
# Q: where does the trabecular bone forming the marrow space show?
# GT: at the margins
# PD: in the right hemisphere, the trabecular bone forming the marrow space shows up in the right hemisphere, the trabecular b
#
# Q: are there inadequate t cells to mount a granulomatous response?
# GT: yes
# PD: no
#
# Q: how does the trabecular bone forming the marrow space show trabeculae?
# GT: with osteoclastic activity
# PD: shows the presence of the bone in the marrow space, which is a sign of the presence of the bone in the marrow space, which is
#
# Q: does the trabecular bone forming the marrow space show trabeculae with osteoclastic activity at the margins?
# GT: yes
# PD: no
#
# Q: does the upper dermis show trabeculae with osteoclastic activity at the margins?
# GT: no
# PD: no
#
# Q: what shows concentric lamellae along with osteocytic lacunae surrounding central blood vessels, while the trabecular bone forming the marrow space shows trabeculae with osteoclastic activity at the margins?
# GT: cortical bone forming the outer shell
# PD: the trabecular bone shows a well-defined trabecular space with a central space of osteoclastic activity, which is the site of
#
# Q: what does the cortical bone forming the outer shell show?
# GT: concentric lamellae along with osteocytic lacunae surrounding central blood vessels
# PD: the brain shows the following:
#
# Q: does the cortical bone forming the outer shell show concentric lamellae along with osteocytic lacunae surrounding central blood vessels, while the trabecular bone forming the marrow space shows trabeculae with osteoclastic activity at the margins?
# GT: yes
# PD: no, the cortical bone forming the outer shell shows a lamellae with osteoclastic activity at the margins, while the trab
#
# Q: does inbox show concentric lamellae along with osteocytic lacunae surrounding central blood vessels, while the trabecular bone forming the marrow space shows trabeculae with osteoclastic activity at the margins?
# GT: no
# PD: no, inbox shows no such image
#
# Q: what begins as a focus of microabscess in a vascular loop in the marrow which expands to stimulate?
# GT: process
# PD: the microabscess in a vascular loop in the marrow which expands to stimulate the vascular loop in the marrow which expands
#
# Q: what does process begin as?
# GT: a focus of microabscess in a vascular loop in the marrow which expands to stimulate
# PD: the body begins to produce the enzyme lacteogenic acid, which is then secreted by the liver and the pancreas, and
#
# Q: does process begin as a focus of microabscess in a vascular loop in the marrow which expands to stimulate?
# GT: yes
# PD: no
#
# Q: what is aids?
# GT: acquired immunodeficiency syndrome
# PD: necrosis of the skin, with the skin and the eyes, and the lungs, and the liver, and the spleen, and
#
# Q: does photomicrograph on right under higher magnification begin as a focus of microabscess in a vascular loop in the marrow which expands to stimulate?
# GT: no
# PD: no
#
# Q: what is there of reactive woven bone formation by the periosteum?
# GT: beginning
# PD: the periosteum
#
# Q: is there beginning of reactive woven bone formation by the periosteum?
# GT: yes
# PD: no
#
# Q: is the cyst wall beginning of reactive woven bone formation by the periosteum?
# GT: no
# PD: no
#
# Q: what expands further causing necrosis of the cortex called sequestrum?
# GT: abscess
# PD: the cortex
#
# Q: what does the abscess expand?
# GT: further causing necrosis of the cortex called sequestrum
# PD: the colonic wall of the rectum and the ileum expand?
#
# Q: does the abscess expand further causing necrosis of the cortex called sequestrum?
# GT: yes
# PD: no
#
# Q: do the alveolar walls expand further causing necrosis of the cortex called sequestrum?
# GT: no
# PD: no
#
# Q: what is called involucrum?
# GT: formation of viable new reactive bone surrounding the sequestrum
# PD: the skin and mucosa of the face, the mouth, and anus, the conjunctiva, the cornea, the iris, the pup
#
# Q: what is the formation of viable new reactive bone surrounding the sequestrum called?
# GT: involucrum
# PD: the formation of viable new reactive bone surrounding the sequestrum called the new reactive bone called the new reactive bone called the new
#
# Q: what is composed of fibrous plaques?
# GT: aorta with mild atherosclerosis
# PD: the endocrine system of the ovary, the uterus, the cervix, the vagina, the vagina, the v
#
# Q: is the formation of viable new reactive bone surrounding the sequestrum called involucrum?
# GT: yes
# PD: no
#
# Q: is an asbestos body called involucrum?
# GT: no
# PD: no
#
# Q: what produces a draining sinus?
# GT: extension of infection into the joint space
# PD: the uterus
#
# Q: what does the extension of infection into the joint space, epiphysis and the skin produce?
# GT: a draining sinus
# PD: the skin produces keratinocytes, which are the main source of keratinocytes in the body, and the joint space is filled with keratinocy
#
# Q: does the extension of infection into the joint space, epiphysis and the skin produce a draining sinus?
# GT: yes
# PD: no
#
# Q: does part of the endocervical mucosa produce a draining sinus?
# GT: no
# PD: no
#
# Q: what is expanded externally due to a gelatinous tumour?
# GT: bone
# PD: the tumour is a large, solid, gelatinous tumour that has spread to the surrounding tissues, causing extensive tissue damage, including the skin
#
# Q: why is the bone expanded?
# GT: due to a gelatinous tumour
# PD: to form the lining of the uterus, the uterus, the ovaries, the cervix, the vagina, the
#
# Q: is the bone expanded externally due to a gelatinous tumour?
# GT: yes
# PD: no
#
# Q: is the basal layer expanded externally due to a gelatinous tumour?
# GT: no
# PD: no
#
# Q: what is aorta with mild atherosclerosis composed of?
# GT: fibrous plaques
# PD: aorta with mild atherosclerosis composed of:
#
# Q: what shows lobulated mass with bluish cartilaginous hue infiltrating the soft tissues?
# GT: sectioned surface
# PD: colonoscopy showing the colonoscopy specimen in the rectum, which is the most common type of colonoscopy, and the colonoscopy spec
#
# Q: how does sectioned surface show lobulated mass?
# GT: with bluish cartilaginous hue infiltrating the soft tissues
# PD: the surface is lobulated, the body is lobulated, the head is lobulated, the neck is lobulated, the face is lo
#
# Q: does sectioned surface show lobulated mass with bluish cartilaginous hue infiltrating the soft tissues?
# GT: yes
# PD: no, it shows a normalized mass with bluish cartilaginous hue infiltrating the soft tissues.
#
# Q: does the amputated head of the long bone show lobulated mass with bluish cartilaginous hue infiltrating the soft tissues?
# GT: no
# PD: no
#
# Q: what is expanded in the region of epiphysis?
# GT: end of the long bone
# PD: the lungs
#
# Q: what is the end of the long bone expanded in?
# GT: region of epiphysis
# PD: the end of the long bone is the end of the long bone, which is the end of the long bone, which is the end of the
#
# Q: where is the end of the long bone expanded?
# GT: in region of epiphysis
# PD: the end of the long bone is the end of the long bone in the body of the human being, which is the end of the long bone
#
# Q: is the end of the long bone expanded in the region of epiphysis?
# GT: yes
# PD: no
#
# Q: is section from margin of amoebic ulcer expanded in the region of epiphysis?
# GT: no
# PD: no
#
# Q: what shows circumscribed, dark tan, haemorrhagic and necrotic tumour?
# GT: sectioned surface
# PD: the tumour shows a dark, haemorrhagic, necrotic, and necrotic appearance, with a dark, necrot
#
# Q: is the aorta with mild atherosclerosis composed of fibrous plaques?
# GT: yes
# PD: no
#
# Q: does sectioned surface show circumscribed, dark tan, haemorrhagic and necrotic tumour?
# GT: yes
# PD: no
#
# Q: does the sectioned surface of rectal wall show circumscribed, dark tan, haemorrhagic and necrotic tumour?
# GT: no
# PD: no
#
# Q: what is expanded in the region of epiphysis?
# GT: end of the long bone
# PD: the gastrointestinal system, including the pancreas, the liver, the spleen, the bone marrow, the adren
#
# Q: what is the end of the long bone expanded in?
# GT: region of epiphysis
# PD: the end of the long bone is the end of the long bone, which is the end of the long bone, which is the end of the
#
# Q: is the end of the long bone expanded in the region of epiphysis?
# GT: yes
# PD: no
#
# Q: is viral dna expanded in the region of epiphysis?
# GT: no
# PD: no
#
# Q: what shows circumscribed, dark tan, haemorrhagic and necrotic tumour?
# GT: sectioned surface
# PD: the tumour shows a dark, haemorrhagic, necrotic, and necrotic appearance, with a dark, necrot
#
# Q: does sectioned surface show circumscribed, dark tan, haemorrhagic and necrotic tumour?
# GT: yes
# PD: no, it shows a normal appearance of the skin, with no signs of tumour, such as the skin, with no signs of tumour, such as
#
# Q: does iron on absorption from upper small intestine show circumscribed, dark tan, haemorrhagic and necrotic tumour?
# GT: no
# PD: no
#
# Q: are characteristic microscopic features irregular lobules of uniform small tumour cells with indistinct cytoplasmic outlines which are separated by fibrous tissue septa having rich vascularity?
# GT: yes
# PD: yes
#
# Q: what shows scattered inflammatory cells, calcification arrowheads, and neovascularization?
# GT: high-power view of the junction of the fibrous cap and core
# PD: the stomach and small intestine
#
# Q: what are also included?
# GT: areas of necrosis and inflammatory infiltrate
# PD: the gastrointestinal tract, the colon, the liver, the pancreas, the spleen, the bone marrow, the
#
# Q: are areas of necrosis and inflammatory infiltrate also included?
# GT: yes
# PD: yes
#
# Q: are the lipofuscin pigment granules also included?
# GT: no
# PD: no
#
# Q: what shows pas positive tumour cells in perivascular location?
# GT: inbox in the right photomicrograph
# PD: the tumour cells are positive for the antibodies in the stroma and in the stroma cells of the tumour, and the ant
#
# Q: what does inbox in the right photomicrograph show?
# GT: pas positive tumour cells in perivascular location
# PD: a small, round, yellow-green, or yellow-green, or yellow-green, or yellow-green, or yellow-green, or yellow-
#
# Q: does inbox in the right photomicrograph show pas positive tumour cells in perivascular location?
# GT: yes
# PD: no
#
# Q: does the cytoplasm show pas positive tumour cells in perivascular location?
# GT: no
# PD: no
#
# Q: what shows a well-differentiated tumour composed of spindle-shaped cells forming interlacing fascicles producing a typical herring-bone pattern?
# GT: microscopy
# PD: the tumour shows a well-differentiated tumour composed of spindle-shaped cells forming interlacing fascicles producing a typical her
#
# Q: what does microscopy show?
# GT: microscopy
# PD: the cellular structure of the organism, including the nucleus, the mitochondria, the endoplasmatic membrane, the cytop
#
# Q: does microscopy show a well-differentiated tumour composed of spindle-shaped cells forming interlacing fascicles producing a typical herring-bone pattern?
# GT: yes
# PD: no, it shows a well-differentiated tumour composed of spindle-shaped cells forming interlacing fascicles producing a typical her
#
# Q: what did high-power view of the junction of the fibrous cap and core show?
# GT: scattered inflammatory cells
# PD: the junction of the fibrous cap and core is seen as a smooth, round, and smooth, round, and smooth, round, and smooth,
#
# Q: does the necrotic tissue show a well-differentiated tumour composed of spindle-shaped cells forming interlacing fascicles producing a typical herring-bone pattern?
# GT: no
# PD: no, the necrotic tissue shows a well-differentiated tumour composed of spindle-shaped cells forming interlacing
#
# Q: what are also seen?
# GT: a few mitotic figures
# PD: in the stomach and small intestine, the duodenum, the ascitesis, the liver, the pancreas, the b
#
# Q: are a few mitotic figures also seen?
# GT: yes
# PD: no
#
# Q: what shows admixture of spindle-shaped pleomorphic cells forming storiform pattern and histiocyte-like round to oval cells?
# GT: tumour
# PD: the tumor cells are spindle-shaped and round, with a storiform pattern and histiocyte-like round cells, forming a stor
#
# Q: what does the tumour show?
# GT: admixture of spindle-shaped pleomorphic cells forming storiform pattern and histiocyte-like round to oval cells
# PD: the tumor shows the characteristic features of a sarcoma, including the presence of the sarcoma cells, which are the main cells of the sarcom
#
# Q: does the tumour show admixture of spindle-shaped pleomorphic cells forming storiform pattern and histiocyte-like round to oval cells?
# GT: yes
# PD: no
#
# Q: does ziehl-neelsen show admixture of spindle-shaped pleomorphic cells forming storiform pattern and histiocyte-like round to oval cells?
# GT: no
# PD: no
#
# Q: is the nuclei of affected tubules soft, lobulated, yellowish and greasy?
# GT: no
# PD: no
#
# Q: what have features of both syncytial and fibroblastic type and form whorled appearance?
# GT: cells
# PD: the skin is rough and dry, with a rough surface, and the eyes are dark brown, with a yellowish tinge, and the mouth is dry,
#
# Q: what do the cells have?
# GT: features of both syncytial and fibroblastic type and form whorled appearance
# PD: none
#
# Q: did the high-power view of the junction of the fibrous cap and core show scattered inflammatory cells, calcification arrowheads, and neovascularization?
# GT: yes
# PD: no, it showed scattered inflammatory cells, calcification arrowheads, and neovascularization
#
# Q: do the cells have features of both syncytial and fibroblastic type and form whorled appearance?
# GT: yes
# PD: yes
#
# Q: do the tips of dermal papillae have features of both syncytial and fibroblastic type and form whorled appearance?
# GT: no
# PD: no
#
# Q: what contain psammoma bodies?
# GT: some of the whorls
# PD: the body is a mass of cells, which are the same as those found in the uterus, and the uterus is a mass of cells,
#
# Q: what do some of the whorls contain?
# GT: psammoma bodies
# PD: the plant cells of the plant, which are the source of the plant cells, are the source of the plant cells, which are the source of the plant cells
#
# Q: do some of the whorls contain psammoma bodies?
# GT: yes
# PD: no
#
# Q: do a gaucher cell in bone marrow contain psammoma bodies?
# GT: no
# PD: no
#
# Q: what shows a separate encapsulated gelatinous mass?
# GT: lower part of the image
# PD: colonies of the common housefly (fugula) in the stomach of a patient with a history of chronic pancreaticitis, which
#
# Q: what does lower part of the image show?
# GT: a separate encapsulated gelatinous mass
# PD: colonoscopy shows the colonoscopy image of the rectum, which is the site of the tumor in the colon. The tumor is a large
#
# Q: does lower part of the image show a separate encapsulated gelatinous mass?
# GT: yes
# PD: no
#
# Q: does hurthle show a separate encapsulated gelatinous mass?
# GT: no
# PD: no
#
# Q: did the cause of reversible injury show scattered inflammatory cells, calcification arrowheads, and neovascularization?
# GT: no
# PD: no, the cause of reversible injury showed scattered inflammatory cells, calcification arrowheads, and neovascularization
#
# Q: what is multilobulated with increased fat while lower part of the image shows a separate encapsulated gelatinous mass?
# GT: main mass
# PD: colon cancer
#
# Q: what is the main mass multilobulated with?
# GT: increased fat while lower part of the image shows a separate encapsulated gelatinous mass
# PD: the main mass multilobulated with?
#
# Q: is the main mass multilobulated with increased fat while lower part of the image shows a separate encapsulated gelatinous mass?
# GT: yes
# PD: no
#
# Q: is pidural haematoma multilobulated with increased fat while lower part of the image shows a separate encapsulated gelatinous mass?
# GT: no
# PD: no
#
# Q: what shows circumscribed?
# GT: cut surface of both the masses
# PD: colon cancer
#
# Q: does the masses show circumscribed?
# GT: no
# PD: no
#
# Q: do collections of histiocytes show circumscribed?
# GT: no
# PD: no, they show uniform morphology with no evidence of histiocytes, which are the main components of the organism, and no evidence of the presence
#
# Q: does this image show opened abdomen in situ excellent example inflamed gut and yellow-green pus?
# GT: yes
# PD: yes
#
# Q: what is present?
# GT: peritoneum
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: is peritoneum present?
# GT: yes
# PD: yes
#
# Q: what does ischemic injury show?
# GT: surface blebs
# PD: the injury shows the presence of the following organs and tissues:
#
# Q: is part of the vessel uninvolved?
# GT: yes
# PD: no
#
# Q: is subdiaphragmatic abscess present?
# GT: no
# PD: no
#
# Q: what is present?
# GT: acute peritonitis
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: is acute peritonitis present?
# GT: yes
# PD: no
#
# Q: where is this area in the body?
# GT: abdomen
# PD: colon and rectal lymphoma, lymphoma, and other lymphomas, including lymphoma, leukemia, and
#
# Q: what is present?
# GT: peritoneum
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: what is present?
# GT: acute peritonitis
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: does this image show opened abdomen with large lesions typical?
# GT: yes
# PD: yes
#
# Q: does omphalocele show opened abdomen with large lesions typical?
# GT: no
# PD: no
#
# Q: what is present?
# GT: peritoneum
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: is peritoneum present?
# GT: yes
# PD: no
#
# Q: is mycobacterium avium infection in a duodenal biopsy from a patient with aids uninvolved?
# GT: no
# PD: no
#
# Q: is omphalocele present?
# GT: no
# PD: no
#
# Q: what is present?
# GT: carcinomatosis
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: is carcinomatosis present?
# GT: yes
# PD: no
#
# Q: is peritoneum present?
# GT: no
# PD: no
#
# Q: where is this area in the body?
# GT: abdomen
# PD: colon and rectal lymphoma, lymphoma, and other lymphomas, including lymphoma, leukemia, and
#
# Q: what is present?
# GT: peritoneum
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: what is present?
# GT: carcinomatosis
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: does this image show opened peritoneal cavity showing cecum and appendix on left side?
# GT: yes
# PD: yes
#
# Q: does omphalocele show opened peritoneal cavity showing cecum and appendix on left side?
# GT: no
# PD: no
#
# Q: what is present?
# GT: abdomen
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: what demonstrate sheets of plump, proliferating spindle cells and slitlike vascular spaces?
# GT: histologic view of the nodular stage
# PD: the cells are large, spindle-shaped, and have a distinctive appearance, with a smooth surface, and are arranged in a dense, compact
#
# Q: is abdomen present?
# GT: yes
# PD: yes
#
# Q: is tuberculous peritonitis present?
# GT: no
# PD: no
#
# Q: what is present?
# GT: situs inversus
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: is situs inversus present?
# GT: yes
# PD: no
#
# Q: is carcinomatosis present?
# GT: no
# PD: no
#
# Q: where is this area in the body?
# GT: abdomen
# PD: colon and rectal lymphoma, lymphoma, and other lymphomas, including lymphoma, leukemia, and
#
# Q: what is present?
# GT: abdomen
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: what is present?
# GT: situs inversus
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: what illustrates pus from the peritoneal cavity?
# GT: case of peritonitis slide
# PD: the peritoneal cavity is the site of the pus from the peritoneal cavity, which is the site of the pus from
#
# Q: what does case of peritonitis slide illustrate?
# GT: pus from the peritoneal cavity
# PD: the peritoneum is the site of infection, and the peritoneum is the site of inflammation, with the inflammation of
#
# Q: did histologic view of the nodular stage demonstrate sheets of plump, proliferating spindle cells and slitlike vascular spaces?
# GT: yes
# PD: yes
#
# Q: does case of peritonitis slide illustrate pus from the peritoneal cavity?
# GT: yes
# PD: no
#
# Q: does acute peritonitis illustrate pus from the peritoneal cavity?
# GT: no
# PD: no
#
# Q: what does this image show?
# GT: case of peritonitis slide illustrates pus from the peritoneal cavity
# PD: colon cancer of the rectum, with a large tumor in the rectum, with a small tumor in the colon, with a large tumor in
#
# Q: does this image show case of peritonitis slide illustrates pus from the peritoneal cavity?
# GT: yes
# PD: yes
#
# Q: does case of peritonitis slide show case of peritonitis slide illustrates pus from the peritoneal cavity?
# GT: no
# PD: no
#
# Q: what is present?
# GT: abdomen
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: is abdomen present?
# GT: yes
# PD: yes
#
# Q: is tuberculous peritonitis present?
# GT: no
# PD: no
#
# Q: what is present?
# GT: pus in test tube
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: is pus in test tube present?
# GT: yes
# PD: no
#
# Q: did periodic acid-schiff demonstrate sheets of plump, proliferating spindle cells and slitlike vascular spaces?
# GT: no
# PD: yes
#
# Q: is subdiaphragmatic abscess present?
# GT: no
# PD: no
#
# Q: where is this area in the body?
# GT: abdomen
# PD: gastrointestinal tract
#
# Q: what illustrates pus from the peritoneal cavity?
# GT: case of peritonitis slide
# PD: the peritoneal cavity is the site of the pus from the peritoneal cavity, which is the site of the pus from
#
# Q: what is present?
# GT: abdomen
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: what is present?
# GT: pus in test tube
# PD: gastrointestinal systemic inflammatory disease with a high risk of mortality
#
# Q: what psoas natural color large ovoid typical sarcoma?
# GT: opened muscle
# PD: small intestine, large bowel, and small intestine, large ovoid, and small intestine, large ovoid, and small int
#
# Q: does opened muscle psoa natural color large ovoid typical sarcoma?
# GT: yes
# PD: no
#
# Q: does carcinomatosis psoa natural color large ovoid typical sarcoma?
# GT: no
# PD: no
#
# Q: what does this image show?
# GT: opened muscle probably psoas natural color large ovoid typical sarcoma
# PD: colon cancer of the small intestine
#
# Q: does this image show opened muscle probably psoas natural color large ovoid typical sarcoma?
# GT: yes
# PD: yes
#
# Q: what is concentric thickening of the left ventricular wall causing?
# GT: reduction in lumen size
# PD: the condition is a rare but serious medical condition that affects the lungs, heart, and blood vessels.
#
# Q: does acute lymphocytic leukemia show opened muscle probably psoas natural color large ovoid typical sarcoma?
# GT: no
# PD: no
#
# Q: what is present?
# GT: abdomen
# PD: gastrointestinal systemic inflammatory disease
#
# Q: is abdomen present?
# GT: yes
# PD: yes
#
# Q: is tuberculous peritonitis present?
# GT: no
# PD: no
#
# Q: what is present?
# GT: peritoneum
# PD: gastrointestinal systemic inflammatory disease
#
# Q: is peritoneum present?
# GT: yes
# PD: yes
#
# Q: is an opened peritoneal cavity cause by fibrous band strangulation present?
# GT: no
# PD: no
#
# Q: what is present?
# GT: retroperitoneal leiomyosarcoma
# PD: gastrointestinal systemic inflammatory disease
#
# Q: is retroperitoneal leiomyosarcoma present?
# GT: yes
# PD: no
#
# Q: where is this area in the body?
# GT: abdomen
# PD: colon and rectal lymphoma, lymphoma, and other lymphomas, including lymphoma, leukemia, and
#
# Q: what is causing reduction in lumen size?
# GT: concentric thickening of the left ventricular wall
# PD: the colon cancer syndrome (ccss) which is a rare but severe form of cancer that affects the gastrointestinal system, including the small
#
# Q: what psoas natural color large ovoid typical sarcoma?
# GT: opened muscle
# PD: small intestine, large bowel, and small intestine, large ovoid, and small intestine, large ovoid, and small int
#
# Q: what is present?
# GT: abdomen
# PD: gastrointestinal systemic inflammatory disease
#
# Q: what is present?
# GT: peritoneum
# PD: gastrointestinal systemic inflammatory disease
#
# Q: what is present?
# GT: retroperitoneal leiomyosarcoma
# PD: gastrointestinal systemic inflammatory disease
#
# Q: how does opened muscle psoa color large ovoid typical sarcoma?
# GT: natural
# PD: normal tissue psoa color large ovoid typical sarcoma?
#
# Q: how does opened muscle psoa natural color ovoid typical sarcoma?
# GT: large
# PD: normal color ovoid typical sarcoma
#
# Q: how does opened muscle psoa natural color large ovoid sarcoma?
# GT: typical
# PD: the tumor is a large, ovoid, necrotic, necrotic, necrotic, necrotic, nec
#
# Q: what shows cut surface with fish flesh appearance and extensive necrosis very good for illustrating appearance of a sarcoma?
# GT: this section showing liver tumor mass in hilar area tumor
# PD: the cut surface with fish flesh appearance and extensive necrosis very good for illustrating appearance of a sarcoma
#
# Q: what does this section showing liver with tumor mass in hilar area tumor show?
# GT: cut surface fish flesh appearance and extensive necrosis very good for illustrating appearance of a sarcoma
# PD: the tumor is located in the liver, which is a common site for tumors, and the liver is enlarged, with a large tum

# %%
# ======================================================
# 11. 评估 Yes/No Accuracy
# ======================================================
test_ds = load_dataset("flaviagiammarino/path-vqa", split="test")
# N = 1800   # 想推理多少条就写多少
# test_ds = test_ds.select(range(N))

def is_yes_no(ans):
    ans = ans.lower().strip()
    return ans in ["yes", "no"]

yesno_samples = [s for s in test_ds if is_yes_no(s["answer"])]
print("Yes/No samples =", len(yesno_samples))

yn_correct = 0
yn_total = len(yesno_samples)

yn_predictions = []

for sample in tqdm(yesno_samples, desc="Eval Yes/No"):
    img = sample["image"]
    question = sample["question"]
    answer_gt = sample["answer"].lower().strip()  # "yes" / "no"

    # --------------------------------------------------
    # 推理
    # --------------------------------------------------
    with torch.no_grad():
        vision_embeds = extract_vision_embeds(img)

        prompt = f"Question: {question}\nAnswer:"
        tok = tokenizer(prompt, return_tensors="pt").to(device)

        text_emb = llama.model.embed_tokens(tok.input_ids)
        inputs_embeds = torch.cat([vision_embeds, text_emb], dim=1)

        output = llama.generate(
            inputs_embeds=inputs_embeds,
            max_new_tokens=8,
            do_sample=False,
        )

        pred = tokenizer.decode(output[0], skip_special_tokens=True)
        pred = pred.split("Answer:")[-1].strip().split("\n")[0].strip().lower()

    # 标准化（避免有些模型输出 like "no," or "yes."）
    pred_clean = "yes" if pred.startswith("y") else ("no" if pred.startswith("n") else pred)

    # 判断
    correct = (pred_clean == answer_gt)
    yn_correct += correct

    yn_predictions.append((question, answer_gt, pred_clean, correct))

# ======================================================
# 输出结果
# ======================================================
print("\n=== Yes/No Accuracy ===")
print(f"Total Yes/No samples = {yn_total}")
print(f"Accuracy = {yn_correct / yn_total:.4f}")

print("\n=== Example Yes/No Predictions ===")
for i in range(15):
    q, gt, pd, ok = yn_predictions[i]
    print(f"Q: {q}")
    print(f"GT: {gt} | Pred: {pd} | Correct: {ok}\n")
# Out:
# Yes/No samples = 3362
# Eval Yes/No: 100%|██████████| 3362/3362 [05:15<00:00, 10.64it/s]
# === Yes/No Accuracy ===
# Total Yes/No samples = 3362
# Accuracy = 0.7606
#
# === Example Yes/No Predictions ===
# Q: does mycobacterium avium infection in a duodenal biopsy from a patient with aids show massive intracellular macrophage infection with acid-fast organisms filamentous and pink in this acid-fast stain preparation?
# GT: yes | Pred: no | Correct: False
#
# Q: does microscopy show branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: yes | Pred: no | Correct: False
#
# Q: does pbf show branching papillae having flbrovascular stalk covered by a single layer of cuboidal cells having ground-glass nuclei?
# GT: no | Pred: no | Correct: True
#
# Q: is chematic mechanisms involved in pathogenesis of two main types of diabetes mellitus?
# GT: yes | Pred: no | Correct: False
#
# Q: are numbers in the illustrations involved in pathogenesis of two main types of diabetes mellitus?
# GT: no | Pred: no | Correct: True
#
# Q: are there inadequate t cells to mount a granulomatous response?
# GT: yes | Pred: no | Correct: False
#
# Q: does the trabecular bone forming the marrow space show trabeculae with osteoclastic activity at the margins?
# GT: yes | Pred: no | Correct: False
#
# Q: does the upper dermis show trabeculae with osteoclastic activity at the margins?
# GT: no | Pred: no | Correct: True
#
# Q: does the cortical bone forming the outer shell show concentric lamellae along with osteocytic lacunae surrounding central blood vessels, while the trabecular bone forming the marrow space shows trabeculae with osteoclastic activity at the margins?
# GT: yes | Pred: no | Correct: False
#
# Q: does inbox show concentric lamellae along with osteocytic lacunae surrounding central blood vessels, while the trabecular bone forming the marrow space shows trabeculae with osteoclastic activity at the margins?
# GT: no | Pred: no | Correct: True
#
# Q: does process begin as a focus of microabscess in a vascular loop in the marrow which expands to stimulate?
# GT: yes | Pred: no | Correct: False
#
# Q: does photomicrograph on right under higher magnification begin as a focus of microabscess in a vascular loop in the marrow which expands to stimulate?
# GT: no | Pred: no | Correct: True
#
# Q: is there beginning of reactive woven bone formation by the periosteum?
# GT: yes | Pred: no | Correct: False
#
# Q: is the cyst wall beginning of reactive woven bone formation by the periosteum?
# GT: no | Pred: no | Correct: True
#
# Q: does the abscess expand further causing necrosis of the cortex called sequestrum?
# GT: yes | Pred: no | Correct: False
